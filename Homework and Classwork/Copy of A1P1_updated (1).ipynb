# %%
import numpy as np

A = np.zeros((5, 5))
domain = [-0.5, -0.2, 0.5, 0.75, 1]

A[:, 0] = 1
for row in range(5):
  for col in range(1, 5):
    A[row, col] = np.power(domain[row], col)
b = np.array([[7.625, 9.3632, 9.625, 8.7578, 8]]).T
a = np.matmul(np.linalg.inv(A), b)
a
# Out:
# array([[ 1.00000084e+01],
#        [ 2.00003368e+00],
#        [-6.00007579e+00],
#        [-1.34736842e-04],
#        [ 2.00016842e+00]])

# %%
from numpy.polynomial import Polynomial
poly = np.poly1d(np.flip(np.squeeze(a)))

# %%
#def poly(x, a):
#  return a[0] * np.power(x, 0) + a[1] * np.power(x, 1) + \
#         a[2] * np.power(x, 2) + a[3] * np.power(x, 3) + \
#         a[4] * np.power(x, 4)

# %%
sample = np.linspace(-2, 2, 100)
fvals = poly(sample)

import matplotlib.pyplot as plt


plt.figure()
plt.plot(sample, fvals)
plt.plot(domain, b, 'ro')

# %%
import numpy as np
import matplotlib.pyplot as plt
f = lambda w, x : w[0] + w[1] * x + w[2] * (x**2) + w[3] * (x**3 )
# sample 20 e q u all y spaced v al u e s between −2 and 2
dom = np.linspace(-2, 2 , 20 )
w = np.random.rand(4)
val = f(w, dom) + np.random.randn(20)/2
valtruth = f(w, dom)
fig,ax = plt.subplots(1 , 1 )
ax.plot(dom, val , 'bx' )
ax.plot(dom, valtruth ,'-g' )
ax.legend([' Noisy samples' ,' Ground truth'])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Noisy sample s and ground truth function' )
# Out:
# Text(0.5, 1.0, 'Noisy sample s and ground truth function')

# %%
A = np.zeros((20,4))
A[:, 0] = 1
for row in range(20):
  for col in range(1,4):
    A[row, col] = np.power(dom[row], col)
b = np.expand_dims(val, axis =1)

w_learned = np.squeeze(np.linalg.lstsq(A,b)[0])
w_learned
val_learned = f(w_learned, dom)

fig,ax = plt.subplots(1 , 1 )
ax.plot(dom, val , 'bx' )
ax.plot(dom, valtruth ,'-g' )
ax.plot(dom, val_learned, '-r')
ax.legend([' Noisy samples' ,' Ground truth'])

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Noisy sample s and ground truth function' )
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
# Text(0.5, 1.0, 'Noisy sample s and ground truth function')
